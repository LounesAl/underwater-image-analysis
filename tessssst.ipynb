# %%
import cv2
import numpy as np

# %%
# Charger l'image
image = cv2.imread("image.jpg")
#image = cv2.resize(image,(768,1024), interpolation = cv2.INTER_AREA)
print(image.shape[:2])
# Out:
# (2048, 1536)

# %%
# Convertir l'image en niveaux de gris
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Appliquer un seuillage pour isoler le contour
_, thresh = cv2.threshold(gray, 100, 255, cv2.THRESH_BINARY)

# Trouver les contours dans l'image
contours, _ = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# Récupérer le contour que l'on souhaite orienter
cnt = [[1,2],[]]

# Calculer la boîte englobante minimale
(x, y), (w, h), angle = cv2.minAreaRect(cnt)

# %%
# Dessiner la boîte englobante sur l'image
box = cv2.boxPoints(((x, y), (w, h), angle))
box = np.int0(box)
cv2.drawContours(image, [box], 0, (0, 0, 255), 2)

# Afficher l'image
cv2_imshow(image)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# Attacher la fonction de callback à la fenêtre d'affichage
cv2.namedWindow("image")
cv2.setMouseCallback("image", on_mouse)

while True:
    # Copie de l'image d'origine
    img = image.copy()

    # Dessiner un rectangle en cours de sélection
    if drag:
        cv2.rectangle(img, start_point, (x,y), (0,255,0), 2)

    # Afficher l'image
    cv2.imshow("image", img)

    # Attente d'une touche pour quitter
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21756/88302235.py in <module>
#       9     # Dessiner un rectangle en cours de sélection
#      10     if drag:
# ---> 11         cv2.rectangle(img, start_point, (x,y), (0,255,0), 2)
#      12
#      13     # Afficher l'image
#
# NameError: name 'start_point' is not defined

# %%
from webcolors import rgb_to_hex
from webcolors import (
    CSS3_HEX_TO_NAMES,
    hex_to_rgb,
)

from scipy.spatial import KDTree

#code RGB (ex: rouge)
rgb = (255, 0, 0)

#conversion en hexadécimal
hex_color = rgb_to_hex(rgb)
#name = rgb_to_name(rgb , spec='css3')
#affichage de la couleur
print(hex_color)
#print(name)

def convert_rgb_to_names(rgb_tuple):
    
    # a dictionary of all the hex and their respective names in css3
    css3_db = CSS3_HEX_TO_NAMES
    names = []
    rgb_values = []
    for color_hex, color_name in css3_db.items():
        names.append(color_name)
        rgb_values.append(hex_to_rgb(color_hex))
    
    kdt_db = KDTree(rgb_values)
    distance, index = kdt_db.query(rgb_tuple)

    return f'{names[index]}'

coul = convert_rgb_to_names(rgb)
print(coul)
# Out:
# #ff0000
# red

# %%
#code pour suivre la couleur d'un objet : 
#bibliotheque : 
import cv2
import numpy as np
from webcolors import rgb_to_hex

def convert_rgb_to_names(rgb_tuple):
    
    # a dictionary of all the hex and their respective names in css3
    css3_db = CSS3_HEX_TO_NAMES
    names = []
    rgb_values = []
    for color_hex, color_name in css3_db.items():
        names.append(color_name)
        rgb_values.append(hex_to_rgb(color_hex))
    
    kdt_db = KDTree(rgb_values)
    distance, index = kdt_db.query(rgb_tuple)

    return f' {names[index]}'


#def get_couleur (nbr_image) : 
#d'abord recuperer toutes les images : 
nbr_image = 10 #(recuperer le nbr d'image)

moy_tot_couleur = []                        #vecteur de la couleur moyenne pour toute le images 
for i in range(nbr_image) : 
    #chargement de l'image :
    image = cv2.imread("image"+i+".jpg")
    #recuperer tous les pixel de l'espèce souhaitée 
    cnt = np.load('Coords'+i+'.npy')
    taille_cnt = len(cnt) 
    pixel = []
    intensite = []

    for j in range (taille_cnt) : 
        pixel = cnt[i]                              #recuperer les pixel 
        intensite.append(image[pixel[0],pixel[1]])  #recuperer les intensité des pixel d'interet 

    moy_couleur = np.empty((3,1))                   #vecteur de la couleur moyenne de chaque image 
    #print(len(moy_couleur))
    for j in range(3):
    #recuperer les colonnes de chaque intensité (R,G,B)
    exec("colonne_" + str(i) + " = np.take(intensite, i, axis=1)")
    #calculer leurs moyennes
    exec("moy_couleur [i]  = np.mean(colonne_"+str(i)+")")
    
    moy_tot_couleur.append(moy_couleur)

#une fois la matrice de couleur remplie nous verrons si on a une difference entre les images 
for i in range(3):
#recuperer chaque colonne des intensités moyennes 
exec("itens" + str(i) + " = np.take(moy_tot_couleur, i, axis=1)")

for i in range (0,nbr_image-1) : 
    #seuil de 10% pour chaque image 
    s = 10
    seuil_0 = (itens0[i]*s)/100
    seuil_1 = (itens1[i]*s)/100
    seuil_2 = (itens2[i]*s)/100

    if ((itens0[i+1] < seuil_0 + itens0[i] and itens0[i+1] > seuil_0 - itens0[i]) or (itens1[i+1] < seuil_1 + itens1[i] and itens1[i+1] > seuil_1 - itens1[i]) or (itens2[i+1] < seuil_2 + itens2[i] and itens2[i+1] > seuil_2 - itens2[i]) ) : 
        print("pas de changement de couleur")

    else : 

        rgb = (itens0[i+1],itens1[i+1],itens2[i+1])

        #conversion en hexadécimal
        color = convert_rgb_to_names(rgb)

        #affichage de la couleur
        print("l'espece change de couleur vers :" color)

# %%
#code pour suivre la couleur d'un objet : 
#bibliotheque : 

from utils.segmentation import *
from webcolors import rgb_to_hex
from webcolors import (
    CSS3_HEX_TO_NAMES,
    hex_to_rgb,
)

import cv2
import numpy as np
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2276/2792719584.py in <module>
#       2 #bibliotheque :
#       3
# ----> 4 from utils.segmentation import *
#       5 from webcolors import rgb_to_hex
#       6 from webcolors import (
#
# ModuleNotFoundError: No module named 'utils'

# %%
def convert_rgb_to_names(rgb_tuple):
    
    # a dictionary of all the hex and their respective names in css3
    css3_db = CSS3_HEX_TO_NAMES
    names = []
    rgb_values = []
    for color_hex, color_name in css3_db.items():
        names.append(color_name)
        rgb_values.append(hex_to_rgb(color_hex))
    
    kdt_db = KDTree(rgb_values)
    distance, index = kdt_db.query(rgb_tuple)

    return f' {names[index]}'

def get_nbr_image (chemin) : 
   #path = 'chemin/vers/dossier'
    files = os.listdir(chemin)
    num_files = len(files)/2
    
    return num_files

#C:\Users\Amel\Documents\GitHub\underwater-image-analysis\data\outputs\output_0.jpg

def get_couleur (num_files , chemin) : 
    #d'abord recuperer toutes les images : 
    #nbr_image = 10 #(recuperer le nbr d'image)

    moy_tot_couleur = []                        #vecteur de la couleur moyenne pour toute le images 
    for i in range(num_files) : 
        #chargement de l'image :
        image = cv2.imread(chemin + "\output_" + str(i*40)+ ".jpg")
        #recuperer tous les pixel de l'espèce souhaitée 

        outputs = np.load('output_'+ str(i*40) +'.npy')

        mask_seg = outputs["instances"].pred_masks.cpu().numpy()
        cnt = get_segmentation(mask_seg)

        taille_cnt = len(cnt) 
        pixel = []
        intensite = []

        for j in range (taille_cnt) : 
            pixel = cnt[i]                              #recuperer les pixel 
            intensite.append(image[pixel[0],pixel[1]])  #recuperer les intensité des pixel d'interet 

        moy_couleur = np.empty((3,1))                   #vecteur de la couleur moyenne de chaque image 
        #print(len(moy_couleur))
        for j in range(3):
            #recuperer les colonnes de chaque intensité (R,G,B)
            exec("colonne_" + str(i) + " = np.take(intensite, i, axis=1)")
            #calculer leurs moyennes
            exec("moy_couleur [i]  = np.mean(colonne_"+str(i)+")")
        
        moy_tot_couleur.append(moy_couleur)

    #une fois la matrice de couleur remplie nous verrons si on a une difference entre les images 
    for i in range(3):
        #recuperer chaque colonne des intensités moyennes 
        exec("itens" + str(i) + " = np.take(moy_tot_couleur, i, axis=1)")

    for i in range (0,num_files-1) : 
        #seuil de 10% pour chaque image 
        s = 10
        seuil_0 = (itens0[i]*s)/100
        seuil_1 = (itens1[i]*s)/100
        seuil_2 = (itens2[i]*s)/100

        if (((itens0[i+1] < seuil_0 + itens0[i]) and (itens0[i+1] > seuil_0 - itens0[i])) or (itens1[i+1] < seuil_1 + itens1[i] and itens1[i+1] > seuil_1 - itens1[i]) or (itens2[i+1] < seuil_2 + itens2[i] and itens2[i+1] > seuil_2 - itens2[i]) ) : 
            print("pas de changement de couleur")

        else : 

            rgb = (itens0[i+1],itens1[i+1],itens2[i+1])
            #conversion en hexadécimal
            color = convert_rgb_to_names(rgb)
            #affichage de la couleur
            print ("lespece change de couleur vers :" , color) 


chemin="C:\Users\Amel\Documents\GitHub\underwater-image-analysis\data\outputs"

nbr = get_nbr_image (chemin)

get_couleur (nbr , chemin)
